# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 5.140336
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.519935
# Minibatch accuracy: 43.8%
# Validation accuracy: 53.1%
# Minibatch loss at step 100: 1.829410
# Minibatch accuracy: 37.5%
# Validation accuracy: 62.7%
# Minibatch loss at step 150: 0.414365
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.6%
# Minibatch loss at step 200: 0.848856
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.6%
# Minibatch loss at step 250: 0.600969
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.6%
# Minibatch loss at step 300: 1.197815
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.7%
# Minibatch loss at step 350: 0.306569
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.8%
# Minibatch loss at step 400: 1.177848
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.3%
# Minibatch loss at step 450: 0.301617
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.7%
# Minibatch loss at step 500: 0.331999
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.9%
# Minibatch loss at step 550: 0.433940
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.5%
# Minibatch loss at step 600: 0.450235
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.0%
# Minibatch loss at step 650: 0.334726
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# Minibatch loss at step 700: 0.375750
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.1%
# Minibatch loss at step 750: 0.141211
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.9%
# Minibatch loss at step 800: 0.517058
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.6%
# Minibatch loss at step 850: 0.670353
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.6%
# Minibatch loss at step 900: 0.599375
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.9%
# Minibatch loss at step 950: 0.992592
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 1000: 1.033610
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.4%
# Test accuracy: 88.8%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 8
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    shape = pool.get_shape().as_list()
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.499498
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.240075
# Minibatch accuracy: 62.5%
# Validation accuracy: 53.4%
# Minibatch loss at step 100: 1.660907
# Minibatch accuracy: 56.2%
# Validation accuracy: 65.8%
# Minibatch loss at step 150: 0.567576
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.1%
# Minibatch loss at step 200: 1.080132
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.3%
# Minibatch loss at step 250: 0.550392
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.1%
# Minibatch loss at step 300: 1.249525
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.5%
# Minibatch loss at step 350: 0.419233
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.3%
# Minibatch loss at step 400: 1.323141
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.2%
# Minibatch loss at step 450: 0.332779
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.0%
# Minibatch loss at step 500: 0.314411
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.2%
# Minibatch loss at step 550: 0.495230
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.2%
# Minibatch loss at step 600: 0.409566
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.6%
# Minibatch loss at step 650: 0.373103
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.5%
# Minibatch loss at step 700: 0.372591
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.2%
# Minibatch loss at step 750: 0.158159
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.8%
# Minibatch loss at step 800: 0.645312
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.6%
# Minibatch loss at step 850: 0.712096
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.1%
# Minibatch loss at step 900: 0.421360
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.8%
# Minibatch loss at step 950: 1.054132
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.5%
# Minibatch loss at step 1000: 0.604461
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.5%
# Test accuracy: 89.9%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 8
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data, train=False):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    shape = pool.get_shape().as_list()
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    if train:
        hidden = tf.nn.dropout(hidden, 0.95)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset, train=True)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))

  batch = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
      0.01,                # Base learning rate.
      batch * batch_size,  # Current index into the dataset.
      train_labels.shape[0],          # Decay step.
      0.9,                # Decay rate.
      staircase=True)
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(loss,
                                                                global_step=batch)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 3001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.263698
# Minibatch accuracy: 6.2%
# Validation accuracy: 11.5%
# Minibatch loss at step 50: 2.421067
# Minibatch accuracy: 6.2%
# Validation accuracy: 9.7%
# Minibatch loss at step 100: 2.240019
# Minibatch accuracy: 18.8%
# Validation accuracy: 17.1%
# Minibatch loss at step 150: 1.925416
# Minibatch accuracy: 43.8%
# Validation accuracy: 33.3%
# Minibatch loss at step 200: 1.775795
# Minibatch accuracy: 50.0%
# Validation accuracy: 45.5%
# Minibatch loss at step 250: 1.366683
# Minibatch accuracy: 68.8%
# Validation accuracy: 57.6%
# Minibatch loss at step 300: 1.358626
# Minibatch accuracy: 68.8%
# Validation accuracy: 69.0%
# Minibatch loss at step 350: 0.698202
# Minibatch accuracy: 87.5%
# Validation accuracy: 70.4%
# Minibatch loss at step 400: 1.512546
# Minibatch accuracy: 62.5%
# Validation accuracy: 70.0%
# Minibatch loss at step 450: 0.804652
# Minibatch accuracy: 62.5%
# Validation accuracy: 76.8%
# Minibatch loss at step 500: 0.592991
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.6%
# Minibatch loss at step 550: 0.764080
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.1%
# Minibatch loss at step 600: 0.651366
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.1%
# Minibatch loss at step 650: 0.682547
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.5%
# Minibatch loss at step 700: 0.657457
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.1%
# Minibatch loss at step 750: 0.354418
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.8%
# Minibatch loss at step 800: 0.779575
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.3%
# Minibatch loss at step 850: 0.663428
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.8%
# Minibatch loss at step 900: 0.900463
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.3%
# Minibatch loss at step 950: 1.258752
# Minibatch accuracy: 62.5%
# Validation accuracy: 80.4%
# Minibatch loss at step 1000: 1.202181
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.8%
# Minibatch loss at step 1050: 0.856183
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.5%
# Minibatch loss at step 1100: 0.671978
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.4%
# Minibatch loss at step 1150: 0.703457
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.1%
# Minibatch loss at step 1200: 0.618669
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.7%
# Minibatch loss at step 1250: 0.822608
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.1%
# Minibatch loss at step 1300: 0.677441
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.0%
# Minibatch loss at step 1350: 0.361366
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.3%
# Minibatch loss at step 1400: 0.669975
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.7%
# Minibatch loss at step 1450: 0.137676
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 1500: 1.186335
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.8%
# Minibatch loss at step 1550: 0.350794
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.8%
# Minibatch loss at step 1600: 0.617926
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Minibatch loss at step 1650: 0.762357
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.6%
# Minibatch loss at step 1700: 0.721870
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.0%
# Minibatch loss at step 1750: 0.496434
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.6%
# Minibatch loss at step 1800: 0.297545
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.1%
# Minibatch loss at step 1850: 0.305525
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.4%
# Minibatch loss at step 1900: 0.426975
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Minibatch loss at step 1950: 0.373820
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.6%
# Minibatch loss at step 2000: 0.680613
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.5%
# Minibatch loss at step 2050: 0.678529
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.3%
# Minibatch loss at step 2100: 0.584672
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.5%
# Minibatch loss at step 2150: 1.236693
# Minibatch accuracy: 62.5%
# Validation accuracy: 83.2%
# Minibatch loss at step 2200: 0.237244
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.7%
# Minibatch loss at step 2250: 0.651164
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.8%
# Minibatch loss at step 2300: 0.698728
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.7%
# Minibatch loss at step 2350: 0.599280
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.6%
# Minibatch loss at step 2400: 0.504531
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.5%
# Minibatch loss at step 2450: 0.407257
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.4%
# Minibatch loss at step 2500: 0.740562
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.4%
# Minibatch loss at step 2550: 0.331063
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.0%
# Minibatch loss at step 2600: 0.689247
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.5%
# Minibatch loss at step 2650: 0.239696
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.2%
# Minibatch loss at step 2700: 0.718873
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.5%
# Minibatch loss at step 2750: 0.773796
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.0%
# Minibatch loss at step 2800: 0.465131
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.5%
# Minibatch loss at step 2850: 0.459341
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.0%
# Minibatch loss at step 2900: 0.198546
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.9%
# Minibatch loss at step 2950: 0.719531
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.2%
# Minibatch loss at step 3000: 0.155384
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.1%
# Test accuracy: 90.2%
